# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
# Replace None with appropriate code

# Import the requests library
import requests

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
api_key = None

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = "pizza"
location = "New York NY"

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(api_key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url, headers = headers, params = url_params)

# Confirm we got a 200 response
response
# Out:
# <Response [200]>

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response.json()['businesses']

# View the first 2 records
businesses[:2]
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=Q8jEyR2ugxRZtgm4VLGuEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q8jEyR2ugxRZtgm4VLGuEQ',
#   'review_count': 4328,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1961.8771417367063},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=Q8jEyR2ugxRZtgm4VLGuEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Q8jEyR2ugxRZtgm4VLGuEQ',
#   'review_count': 2440,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 308.56984360837544}]

# %%
businesses[1].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'price', 'location', 'phone', 'display_phone', 'distance'])

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
# Replace None with appropriate code

def prepare_data(data_list):
    """
    This function takes in a list of dictionaries and prepares it
    for analysis
    """
    
    # Make a new list to hold results
    results = []
    
    for business_data in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {}
        
        # Extract name, review_count, rating, and price key-value pairs
        # from business_data and add to prepared_data
        # If a key is not present in business_data, add it to prepared_data
        # with an associated value of None
        for k in ("name", "review_count", "rating", "price"):
            prepared_data[k] = business_data.get(k,None)
    
        # Parse and add latitude and longitude columns
        prepared_data["latitude"] = business_data["coordinates"]["latitude"]
        prepared_data["longitude"] = business_data["coordinates"]["longitude"]
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses[:5]
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4328,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2440,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6309,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': 'Lucali',
#   'review_count': 1790,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': "Roberta's",
#   'review_count': 3093,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399}]

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 20
# Prepared: 20

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 12000

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = 1000

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Replace None with appropriate code
def get_offsets(total):
    """
    Get a list of offsets needed to get all pages
    of data up until the total
    """
    return list(range(0,total,50))

# %% [markdown]
# Check that your function works below:

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params
# Out:
# {'term': 'pizza', 'location': 'New+York+NY', 'limit': 50}

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

for offset in get_offsets(total):
    # Add or update the "offset" key-value pair in url_params
    url_params["offset"] = offset
    
    # Make the query and get the response
    response = requests.get(url, headers=headers, params=url_params)
    
    # Get the response body in JSON format
    response_json = response.json()
    
    # Get the list of businesses from the response_json
    businesses = response_json["businesses"]
    
    # Call the prepare_data function to get a list of processed data
    prepared_businesses = prepare_data(businesses)
    
    # Extend full_dataset with this list (don't append, or you'll get
    # a list of lists instead of a flat list)
    full_dataset.extend( prepared_businesses)

# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
# Out:
# 790

# %%
len(full_dataset)
# Out:
# 790

# %%
full_dataset
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4328,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2440,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6309,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': 'Lucali',
#   'review_count': 1790,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': 'Rubirosa',
#   'review_count': 2644,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Joe's Pizza",
#   'review_count': 2809,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997},
#  {'name': "Roberta's",
#   'review_count': 3093,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': "Joe's Pizza",
#   'review_count': 980,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73331,
#   'longitude': -73.98763},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4774,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.702583,
#   'longitude': -73.9932413},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3748,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2259,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': "Lombardo's of Bay Ridge",
#   'review_count': 169,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.634741,
#   'longitude': -74.0284259},
#  {'name': "Joe's Pizza",
#   'review_count': 1490,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': 'East Village Pizza',
#   'review_count': 420,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.728199,
#   'longitude': -73.985182},
#  {'name': "Joe's Pizza",
#   'review_count': 391,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7168952,
#   'longitude': -73.95892996733771},
#  {'name': 'Gelso & Grand',
#   'review_count': 1214,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7194089547259,
#   'longitude': -73.9973777877722},
#  {'name': "Joe's Pizza",
#   'review_count': 329,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': 'Bleecker Street Pizza',
#   'review_count': 2593,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7320627016512,
#   'longitude': -74.0036552270137},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 688,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': "Paulie Gee's",
#   'review_count': 1311,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': "Lil Frankie's",
#   'review_count': 1327,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723625,
#   'longitude': -73.988555},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4073,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': 'Nolita Pizza',
#   'review_count': 136,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': 'Roebling Pizza',
#   'review_count': 129,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7084890714263,
#   'longitude': -73.9610940711639},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2220,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': "Scarr's Pizza",
#   'review_count': 570,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71534,
#   'longitude': -73.9914},
#  {'name': "Rosa's Pizza",
#   'review_count': 160,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7139499,
#   'longitude': -73.95563},
#  {'name': "Giuseppina's",
#   'review_count': 339,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 578,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': 'Olio e Più',
#   'review_count': 3252,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927},
#  {'name': 'L & B Spumoni Gardens',
#   'review_count': 4191,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.594715,
#   'longitude': -73.981316},
#  {'name': 'Champion Pizza',
#   'review_count': 381,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 671,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': 'Brunetti Pizza',
#   'review_count': 327,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73829,
#   'longitude': -74.0054},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 263,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 615,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76458,
#   'longitude': -73.98247},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 299,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1211,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76388,
#   'longitude': -73.98821},
#  {'name': 'Norma',
#   'review_count': 525,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743553,
#   'longitude': -73.980026},
#  {'name': 'Front Street Pizza',
#   'review_count': 410,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 204,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': 'Marinara Pizza',
#   'review_count': 300,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': 'Village Square Pizza',
#   'review_count': 224,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'Song E Napule',
#   'review_count': 605,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': 'Da Andrea',
#   'review_count': 1275,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.736218,
#   'longitude': -73.99597},
#  {'name': 'Razza Pizza Artigianale',
#   'review_count': 1039,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7177490485075,
#   'longitude': -74.0441924355125},
#  {'name': 'Marta',
#   'review_count': 931,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7445882,
#   'longitude': -73.9847936},
#  {'name': "Ace's Pizza",
#   'review_count': 84,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': "Dellarocco's",
#   'review_count': 314,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': 'Barboncino Pizza & Bar',
#   'review_count': 1052,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67206,
#   'longitude': -73.95717},
#  {'name': 'La Lanterna Di Vittorio',
#   'review_count': 1558,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73069,
#   'longitude': -74.00015},
#  {'name': "Arturo's",
#   'review_count': 722,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7273563342024,
#   'longitude': -74.0004944801331},
#  {'name': "Luigi's Pizza",
#   'review_count': 395,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.66163,
#   'longitude': -73.99334},
#  {'name': 'Milkflower',
#   'review_count': 719,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7628961,
#   'longitude': -73.9207081},
#  {'name': "MAMA'S TOO!",
#   'review_count': 538,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': 'Lions & Tigers & Squares Detroit Pizza',
#   'review_count': 508,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74506,
#   'longitude': -73.99834},
#  {'name': "Peppino's Brick Oven Pizza & Restaurant",
#   'review_count': 469,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.668221,
#   'longitude': -73.986936},
#  {'name': "Carmine's Pizzeria",
#   'review_count': 486,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.714987,
#   'longitude': -73.94414},
#  {'name': 'Barano',
#   'review_count': 295,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 611,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': 'Sotto 13',
#   'review_count': 996,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': "Roberta's Pizza",
#   'review_count': 234,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754393,
#   'longitude': -73.976103},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 273,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': "Patrizia's Pizza and Pasta",
#   'review_count': 697,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7398415,
#   'longitude': -73.9792862},
#  {'name': 'La Nonna Krispy Krust Pizza',
#   'review_count': 63,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.717953,
#   'longitude': -73.9637027},
#  {'name': 'Motorino Pizzeria Napoletana',
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7104799,
#   'longitude': -73.96351},
#  {'name': 'Il Porto Ristorante & Wood Fired Pizza',
#   'review_count': 355,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': 'Piz-zetta',
#   'review_count': 311,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895},
#  {'name': 'Leuca',
#   'review_count': 377,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': "Adrienne's Pizzabar",
#   'review_count': 1750,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7043362,
#   'longitude': -74.0101733},
#  {'name': 'Patzeria Perfect Pizza',
#   'review_count': 1695,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.759494511551836,
#   'longitude': -73.98673451962638},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 408,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279},
#  {'name': 'San Matteo Pizzeria e Cucina',
#   'review_count': 355,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7746799,
#   'longitude': -73.95443},
#  {'name': 'Ribalta Pizza',
#   'review_count': 664,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7334346,
#   'longitude': -73.9916923},
#  {'name': 'IL Brigante',
#   'review_count': 453,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707492,
#   'longitude': -74.002571},
#  {'name': 'Little Italy Pizza',
#   'review_count': 143,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7081041823001,
#   'longitude': -74.0046897976739},
#  {'name': 'Garlic New York Pizza Bar',
#   'review_count': 463,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74514,
#   'longitude': -73.97584},
#  {'name': 'My Pie Pizzeria Romana',
#   'review_count': 827,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7608512,
#   'longitude': -73.9694809},
#  {'name': 'Sofia Pizza Shoppe',
#   'review_count': 235,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75674,
#   'longitude': -73.96431},
#  {'name': 'Made In New York Pizza',
#   'review_count': 382,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.783841,
#   'longitude': -73.977569},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1642,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 176,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': "Vic's",
#   'review_count': 524,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72693,
#   'longitude': -73.99319},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71822,
#   'longitude': -73.99123},
#  {'name': 'Speedy Romeo',
#   'review_count': 638,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6875154792236,
#   'longitude': -73.959874469611},
#  {'name': "Roey's",
#   'review_count': 135,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73596,
#   'longitude': -74.00093},
#  {'name': 'Anna Maria Pizza',
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7179537220535,
#   'longitude': -73.9574498958145},
#  {'name': 'Emmy Squared Pizza: East Village - New York',
#   'review_count': 323,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72598,
#   'longitude': -73.98672},
#  {'name': 'Neapolitan Express',
#   'review_count': 6,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77991,
#   'longitude': -73.9818},
#  {'name': 'Upside Pizza',
#   'review_count': 187,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7550912,
#   'longitude': -73.9911494},
#  {'name': 'Fornino',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69813,
#   'longitude': -73.98848},
#  {'name': 'Best Pizza',
#   'review_count': 657,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7156,
#   'longitude': -73.95352},
#  {'name': 'Table 87 - Brooklyn Heights',
#   'review_count': 315,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.691219329834,
#   'longitude': -73.9973449707031},
#  {'name': 'Kesté Pizza & Vino',
#   'review_count': 1486,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7093947,
#   'longitude': -74.0048977},
#  {'name': 'TAPPO NYCThinCrust Pizza',
#   'review_count': 528,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74337,
#   'longitude': -73.99153},
#  {'name': 'Emmy Squared Pizza - Brooklyn',
#   'review_count': 711,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.712168,
#   'longitude': -73.955707},
#  {'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 981,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76492,
#   'longitude': -73.97794},
#  {'name': 'Luna Pizza',
#   'review_count': 95,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.713245675315,
#   'longitude': -73.998651104496},
#  {'name': 'Enzo Bruni Pizza Gourmet',
#   'review_count': 72,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.783433,
#   'longitude': -73.947932},
#  {'name': 'Unregular Pizza',
#   'review_count': 102,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73398,
#   'longitude': -73.98961},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 235,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72892,
#   'longitude': -73.98411},
#  {'name': 'Emporio',
#   'review_count': 833,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.722647,
#   'longitude': -73.995246},
#  {'name': 'Ops',
#   'review_count': 168,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 52,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7264595,
#   'longitude': -73.9895782},
#  {'name': 'Follia',
#   'review_count': 255,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7349243164062,
#   'longitude': -73.9855880737305},
#  {'name': 'Double Zero',
#   'review_count': 579,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7261288,
#   'longitude': -73.9896645},
#  {'name': 'Emily - West Village',
#   'review_count': 839,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.729330068469,
#   'longitude': -74.0038400073579},
#  {'name': 'Fascati Pizza',
#   'review_count': 253,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6985,
#   'longitude': -73.99273},
#  {'name': 'Paesano of Mulberry Street',
#   'review_count': 1172,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718554,
#   'longitude': -73.997447},
#  {'name': 'Triangolo Pizza',
#   'review_count': 123,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73357,
#   'longitude': -73.955116},
#  {'name': 'Levante',
#   'review_count': 292,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74764,
#   'longitude': -73.94173},
#  {'name': 'Tailfeather',
#   'review_count': 25,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.69415,
#   'longitude': -73.96089},
#  {'name': 'Leo',
#   'review_count': 51,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': 'Proto’s Pizza',
#   'review_count': 106,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 67,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': "Grimaldi's",
#   'review_count': 788,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7412157,
#   'longitude': -73.9938935},
#  {'name': 'Saraghina Pizzeria',
#   'review_count': 952,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6837407,
#   'longitude': -73.9353473},
#  {'name': "Ignazio's",
#   'review_count': 575,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.703137,
#   'longitude': -73.993608},
#  {'name': "Denino's Pizzeria & Tavern",
#   'review_count': 806,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448},
#  {'name': 'Don Antonio',
#   'review_count': 1528,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.762711,
#   'longitude': -73.986708},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 738,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': 'Montesacro Pinseria Brooklyn',
#   'review_count': 194,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71338,
#   'longitude': -73.95136},
#  {'name': "Rao's",
#   'review_count': 196,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.79392,
#   'longitude': -73.93427},
#  {'name': "Rosa's Pizza",
#   'review_count': 417,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': 'Adoro Lei',
#   'review_count': 335,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': 'Emily',
#   'review_count': 861,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68351,
#   'longitude': -73.96643},
#  {'name': 'Sauce',
#   'review_count': 877,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7204716,
#   'longitude': -73.9893263},
#  {'name': "Screamer's Pizzeria",
#   'review_count': 408,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7235518,
#   'longitude': -73.95065},
#  {'name': 'Baci & Abbracci',
#   'review_count': 333,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7139015197754,
#   'longitude': -73.96044921875},
#  {'name': "Saluggi's",
#   'review_count': 577,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.720131370119134,
#   'longitude': -74.00362290743904},
#  {'name': '2 Bros Pizza',
#   'review_count': 610,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72866,
#   'longitude': -73.988487},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 887,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.797157,
#   'longitude': -73.93488},
#  {'name': "Emmett's",
#   'review_count': 567,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727303,
#   'longitude': -74.00243},
#  {'name': 'PizzArte',
#   'review_count': 1177,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7629335072372,
#   'longitude': -73.9776668697596},
#  {'name': 'Tavola',
#   'review_count': 1098,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.755403,
#   'longitude': -73.994516},
#  {'name': '2 Bros Pizza',
#   'review_count': 421,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75678,
#   'longitude': -73.98022},
#  {'name': "Graziella's",
#   'review_count': 467,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6904563903809,
#   'longitude': -73.9696273803711},
#  {'name': "Freddie & Pepper's",
#   'review_count': 497,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.779999,
#   'longitude': -73.980301},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 283,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.750427,
#   'longitude': -73.972129},
#  {'name': 'Lunetta Pizza & Restaurant',
#   'review_count': 159,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.736942,
#   'longitude': -73.984176},
#  {'name': "Tony's Di Napoli",
#   'review_count': 769,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76441,
#   'longitude': -73.96427},
#  {'name': 'Union Pizza Works',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7073067,
#   'longitude': -73.922154},
#  {'name': 'Brooklyn Pizza Market',
#   'review_count': 110,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68273,
#   'longitude': -73.99305},
#  {'name': "Manetta's Ristorante",
#   'review_count': 417,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7427,
#   'longitude': -73.95184},
#  {'name': "Denino's Greenwich Village",
#   'review_count': 235,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7294,
#   'longitude': -74.00111},
#  {'name': "Beebe's",
#   'review_count': 157,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754827,
#   'longitude': -73.935918},
#  {'name': 'Upside Pizza',
#   'review_count': 26,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75157,
#   'longitude': -73.98059},
#  {'name': "Louie's Pizza",
#   'review_count': 484,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7459,
#   'longitude': -73.8834},
#  {'name': 'San Marino Ristorante',
#   'review_count': 183,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72697,
#   'longitude': -74.00611},
#  {'name': 'Pizza Italia',
#   'review_count': 232,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7419889767239,
#   'longitude': -74.0019458249749},
#  {'name': 'Spunto',
#   'review_count': 456,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7297584,
#   'longitude': -74.0046303},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 71,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7204894,
#   'longitude': -73.98927},
#  {'name': 'New Park Pizza',
#   'review_count': 903,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6627403949909,
#   'longitude': -73.8403776268684},
#  {'name': 'Little Italy Pizza',
#   'review_count': 548,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756482,
#   'longitude': -73.981484},
#  {'name': 'Pizza Moto',
#   'review_count': 216,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6746224,
#   'longitude': -74.0007999},
#  {'name': 'Luzzos La Pizza Napoletana',
#   'review_count': 1062,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.730616,
#   'longitude': -73.9834846},
#  {'name': "Vinnie's Pizzeria",
#   'review_count': 713,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7189,
#   'longitude': -73.956843},
#  {'name': 'Shelter Pizza',
#   'review_count': 326,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': '&pizza - Astor Place',
#   'review_count': 198,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729798,
#   'longitude': -73.9926904},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 90,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71087,
#   'longitude': -73.95069},
#  {'name': 'Shelter Pizza',
#   'review_count': 326,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.71967,
#   'longitude': -73.9608499},
#  {'name': '&pizza - Astor Place',
#   'review_count': 198,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729798,
#   'longitude': -73.9926904},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 90,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71087,
#   'longitude': -73.95069},
#  {'name': 'Casa Theodoro',
#   'review_count': 130,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75693,
#   'longitude': -73.906747},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 338,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7078768,
#   'longitude': -73.9507711},
#  {'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 336,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.699286,
#   'longitude': -73.918724},
#  {'name': 'Numero 28 Pizzeria - West Village',
#   'review_count': 485,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73012,
#   'longitude': -74.00275},
#  {'name': 'Santa Panza',
#   'review_count': 201,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'Time Out Market New York',
#   'review_count': 346,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70342863348067,
#   'longitude': -73.99214637055226},
#  {'name': "Tony's Di Napoli",
#   'review_count': 2303,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75641,
#   'longitude': -73.98547},
#  {'name': 'Champion Pizza',
#   'review_count': 147,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Village Pizza',
#   'review_count': 141,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73927,
#   'longitude': -74.00321},
#  {'name': 'Underground Pizza',
#   'review_count': 309,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70499,
#   'longitude': -74.00961},
#  {'name': 'Table 87 - Gowanus',
#   'review_count': 389,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.670664,
#   'longitude': -73.991371},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 637,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': 'VEZZO NYCThinCrust Pizza',
#   'review_count': 1334,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.744435447210506,
#   'longitude': -73.9814189},
#  {'name': 'BRADO NYCThinCrust Pizza',
#   'review_count': 152,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6905570310882,
#   'longitude': -73.99494681265617},
#  {'name': '&pizza - Wall St',
#   'review_count': 129,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7057647,
#   'longitude': -74.0085474},
#  {'name': 'Fornino- Greenpoint',
#   'review_count': 240,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.728949,
#   'longitude': -73.953999},
#  {'name': "Fiore's Pizza",
#   'review_count': 203,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72885,
#   'longitude': -74.00001},
#  {'name': 'Piacere',
#   'review_count': 684,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7196979,
#   'longitude': -73.9951175},
#  {'name': 'GRUPPO NYCThinCrust Pizza',
#   'review_count': 262,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72474,
#   'longitude': -73.98161},
#  {'name': '5 Boroughs Pizza',
#   'review_count': 32,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72138,
#   'longitude': -74.00497},
#  {'name': 'Pizzette',
#   'review_count': 49,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70858,
#   'longitude': -73.94357},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 375,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': "Fazio's",
#   'review_count': 192,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69442,
#   'longitude': -73.91039},
#  {'name': 'Celeste Restaurant',
#   'review_count': 945,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.78666,
#   'longitude': -73.97599},
#  {'name': "Luzzo's BK",
#   'review_count': 205,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.690706,
#   'longitude': -73.9952269},
#  {'name': 'Il Corallo Trattoria',
#   'review_count': 1078,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7262073,
#   'longitude': -74.0018919},
#  {'name': "Famous Ben's Pizza",
#   'review_count': 364,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7249388,
#   'longitude': -74.002451},
#  {'name': 'Famous Calabria',
#   'review_count': 94,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.711942,
#   'longitude': -73.999349},
#  {'name': 'Stromboli Pizza',
#   'review_count': 252,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72778,
#   'longitude': -73.9854299},
#  {'name': 'San Matteo Pizza and Espresso Bar',
#   'review_count': 532,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7804,
#   'longitude': -73.95012},
#  {'name': "Cecconi's Dumbo",
#   'review_count': 922,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7033063330116,
#   'longitude': -73.9916549604523},
#  {'name': "Dani's House of Pizza",
#   'review_count': 1103,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7090018174257,
#   'longitude': -73.830498211479},
#  {'name': 'Oregano',
#   'review_count': 456,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7190165,
#   'longitude': -73.9586248},
#  {'name': "Percy's Pizza",
#   'review_count': 245,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.729076,
#   'longitude': -74.001534},
#  {'name': 'Lo Duca Pizza',
#   'review_count': 135,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059},
#  {'name': "Ganni's Pizza",
#   'review_count': 112,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.69419,
#   'longitude': -73.957809},
#  {'name': "Ovest Pizzoteca by Luzzo's",
#   'review_count': 569,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7507476806641,
#   'longitude': -74.0030212402344},
#  {'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4026,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75749,
#   'longitude': -73.98662},
#  {'name': "J's Pizza",
#   'review_count': 137,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398164,
#   'longitude': -73.9989453},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 316,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': "Saluggi's East",
#   'review_count': 118,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.715948062187,
#   'longitude': -73.9873785183775},
#  {'name': 'Two Boots East Village',
#   'review_count': 400,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.723658440431656,
#   'longitude': -73.98503439649534},
#  {'name': 'Corner Slice',
#   'review_count': 139,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7623377,
#   'longitude': -73.9967579},
#  {'name': "Rosa's Pizza",
#   'review_count': 293,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.712192,
#   'longitude': -73.899997},
#  {'name': "Angelo's Pizza",
#   'review_count': 605,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7638169909039,
#   'longitude': -73.9827420901337},
#  {'name': "Alphonso's Pizzeria & Trattoria",
#   'review_count': 142,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7143,
#   'longitude': -73.98172},
#  {'name': 'Neapolitan Express',
#   'review_count': 215,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.707015,
#   'longitude': -74.009735},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 907,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7298659578295,
#   'longitude': -74.0007890374328},
#  {'name': 'Swift',
#   'review_count': 362,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727309,
#   'longitude': -73.992387},
#  {'name': 'Keste Wall Street',
#   'review_count': 229,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70907785865903,
#   'longitude': -74.00453980520689},
#  {'name': 'Little Italy Pizza',
#   'review_count': 98,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74047547591752,
#   'longitude': -73.98757619999999},
#  {'name': "Rizzo's Fine Pizza",
#   'review_count': 635,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76335,
#   'longitude': -73.91516},
#  {'name': 'Uva',
#   'review_count': 2568,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7722,
#   'longitude': -73.95566},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 237,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': 'Parm',
#   'review_count': 387,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.713993,
#   'longitude': -74.015647},
#  {'name': 'Gnocco',
#   'review_count': 534,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72713,
#   'longitude': -73.9802799},
#  {'name': 'Patsy’s Pizzeria',
#   'review_count': 431,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.76177,
#   'longitude': -73.96575},
#  {'name': "Joe & Sal's Pizza",
#   'review_count': 171,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.669299,
#   'longitude': -73.958753},
#  {'name': 'Don Angie',
#   'review_count': 525,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73778,
#   'longitude': -74.00197},
#  {'name': 'Slice Pizza',
#   'review_count': 47,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75202,
#   'longitude': -73.97376},
#  {'name': "Sicily's Best Pizzeria",
#   'review_count': 83,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70517,
#   'longitude': -73.915155},
#  {'name': 'Motorino',
#   'review_count': 1096,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.73039,
#   'longitude': -73.98381},
#  {'name': 'Anytime Kitchen ',
#   'review_count': 2070,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.74776270790539,
#   'longitude': -73.9867793576711},
#  {'name': 'La Vera Pizzeria',
#   'review_count': 56,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74067,
#   'longitude': -73.98218},
#  {'name': 'Stanton Street Pizza',
#   'review_count': 189,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72075430224113,
#   'longitude': -73.98668599999999},
#  {'name': 'Sauce & Barrel',
#   'review_count': 502,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707999,
#   'longitude': -74.0142651},
#  {'name': 'Rosario Pizza',
#   'review_count': 21,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6941599,
#   'longitude': -73.91848},
#  {'name': "Frank's Trattoria",
#   'review_count': 154,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.73612,
#   'longitude': -73.979473},
#  {'name': 'Delmar Pizzeria',
#   'review_count': 235,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.58615,
#   'longitude': -73.95235},
#  {'name': 'Krispy Pizza ',
#   'review_count': 290,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62236,
#   'longitude': -74.0055},
#  {'name': 'Donna Margherita',
#   'review_count': 136,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76652,
#   'longitude': -73.9598},
#  {'name': "John's of Times Square",
#   'review_count': 2229,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75823,
#   'longitude': -73.98836},
#  {'name': 'Eataly NYC Downtown',
#   'review_count': 1091,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.709716,
#   'longitude': -74.011714},
#  {'name': "Nick's Pizza",
#   'review_count': 561,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78272735790179,
#   'longitude': -73.9478073},
#  {'name': 'Numero 28 Pizzeria Napoletana',
#   'review_count': 550,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73041,
#   'longitude': -73.98595},
#  {'name': 'Wheated',
#   'review_count': 348,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6465968960541,
#   'longitude': -73.9704950265688},
#  {'name': 'The 3 Luigis',
#   'review_count': 94,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6882597,
#   'longitude': -73.9626018},
#  {'name': "Napoli's Pizza",
#   'review_count': 166,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73937,
#   'longitude': -74.03483},
#  {'name': "Mike's Pizza",
#   'review_count': 135,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75214,
#   'longitude': -73.934339},
#  {'name': 'New York Pizza',
#   'review_count': 126,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 31.086427,
#   'longitude': -97.753939},
#  {'name': 'Eleven B',
#   'review_count': 226,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72745,
#   'longitude': -73.97974},
#  {'name': "Rosario's",
#   'review_count': 176,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77489721657789,
#   'longitude': -73.91191391165746},
#  {'name': "Armando's Pizza",
#   'review_count': 68,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6835403,
#   'longitude': -73.9111862},
#  {'name': 'Previti Pizza',
#   'review_count': 429,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7509380299598,
#   'longitude': -73.9767879766344},
#  {'name': 'Ci Siamo',
#   'review_count': 114,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7532112,
#   'longitude': -73.998305},
#  {'name': 'Lexington Pizza Parlour',
#   'review_count': 239,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.789283,
#   'longitude': -73.9487429},
#  {'name': "Totonno's",
#   'review_count': 816,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.578913225666966,
#   'longitude': -73.98383392883555},
#  {'name': 'Solo Pizza',
#   'review_count': 196,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7223854064941,
#   'longitude': -73.98291015625},
#  {'name': 'Obicà Mozzarella Bar Pizza e Cucina',
#   'review_count': 477,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7400486,
#   'longitude': -73.9893018},
#  {'name': "Lena's Italian Kitchen",
#   'review_count': 286,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.742664,
#   'longitude': -73.977783},
#  {'name': 'Inatteso Pizzabar',
#   'review_count': 333,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7056571,
#   'longitude': -74.0172056},
#  {'name': 'La Bellezza',
#   'review_count': 282,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7557792663574,
#   'longitude': -73.9720153808594},
#  {'name': 'Moustache',
#   'review_count': 387,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7323545516408,
#   'longitude': -74.0052938207627},
#  {'name': 'Oath Pizza - East 67th Street',
#   'review_count': 226,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7664835,
#   'longitude': -73.9633564},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 118,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.733114,
#   'longitude': -73.9995607},
#  {'name': 'Liberty Pizzeria',
#   'review_count': 38,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.693225,
#   'longitude': -73.966018},
#  {'name': 'Siena Pizza & Cannoli',
#   'review_count': 54,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.708152,
#   'longitude': -74.013864},
#  {'name': 'Koronet Pizza',
#   'review_count': 652,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.8044212,
#   'longitude': -73.96610978649716},
#  {'name': 'Malaparte',
#   'review_count': 368,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73687,
#   'longitude': -74.00812},
#  {'name': 'Da Gennaro',
#   'review_count': 1143,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.71832,
#   'longitude': -73.99794},
#  {'name': 'Nonnas 1977',
#   'review_count': 157,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76851,
#   'longitude': -73.90997},
#  {'name': 'Babbalucci',
#   'review_count': 441,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80894,
#   'longitude': -73.94496},
#  {'name': 'Osteria Morini',
#   'review_count': 1222,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7219179851303,
#   'longitude': -73.9976472073402},
#  {'name': 'Zia Maria - Chelsea',
#   'review_count': 282,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7454863,
#   'longitude': -73.9993392},
#  {'name': 'Loring Place',
#   'review_count': 480,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435},
#  {'name': 'Zero Otto Nove',
#   'review_count': 495,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7407551035259,
#   'longitude': -73.9914887388588},
#  {'name': "Lazzara's Pizza",
#   'review_count': 308,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.754057,
#   'longitude': -73.989497},
#  {'name': 'Biga Bite',
#   'review_count': 141,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72123,
#   'longitude': -73.98408},
#  {'name': 'Eataly NYC Flatiron',
#   'review_count': 5816,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74200824886595,
#   'longitude': -73.98993910744127},
#  {'name': 'Circa Brewing',
#   'review_count': 378,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Champion Pizza',
#   'review_count': 84,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73592407559118,
#   'longitude': -73.99391475241151},
#  {'name': 'Highline Pizzeria',
#   'review_count': 158,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.751049,
#   'longitude': -74.0020523},
#  {'name': 'San Marzano Pasta Fresca',
#   'review_count': 1364,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727966,
#   'longitude': -73.988382},
#  {'name': "Louie & Ernie's Pizza",
#   'review_count': 337,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.838288,
#   'longitude': -73.828563},
#  {'name': 'Pazza Notte',
#   'review_count': 919,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7635099,
#   'longitude': -73.978},
#  {'name': 'Quality Italian',
#   'review_count': 1233,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7644044527436,
#   'longitude': -73.9767805051616},
#  {'name': 'Roma Pizza',
#   'review_count': 357,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.77843,
#   'longitude': -73.94863},
#  {'name': "Monte's",
#   'review_count': 164,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6775499,
#   'longitude': -73.98724},
#  {'name': 'Fumo Pizza-Bar-Pasta',
#   'review_count': 528,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.821427,
#   'longitude': -73.950638},
#  {'name': 'Two Boots Pizza - West Village',
#   'review_count': 39,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73308,
#   'longitude': -74.00277},
#  {'name': "Luzzo's Neapolitan Pizza & Wine Bar",
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7492468,
#   'longitude': -73.9420071},
#  {'name': 'Osteria Brooklyn',
#   'review_count': 105,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.693154,
#   'longitude': -73.967177},
#  {'name': 'Fumo Pizza-Bar-Pasta',
#   'review_count': 528,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.821427,
#   'longitude': -73.950638},
#  {'name': 'Two Boots Pizza - West Village',
#   'review_count': 39,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73308,
#   'longitude': -74.00277},
#  {'name': "Luzzo's Neapolitan Pizza & Wine Bar",
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7492468,
#   'longitude': -73.9420071},
#  {'name': 'Osteria Brooklyn',
#   'review_count': 105,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.693154,
#   'longitude': -73.967177},
#  {'name': 'Picasso Pizza',
#   'review_count': 138,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.710402,
#   'longitude': -74.016469},
#  {'name': 'Sunnyside Pizza',
#   'review_count': 434,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7438380472824,
#   'longitude': -73.9241266284942},
#  {'name': "Jeannie's",
#   'review_count': 20,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7662427,
#   'longitude': -73.98124349999999},
#  {'name': '2 Bros Pizza',
#   'review_count': 285,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7443525488053,
#   'longitude': -73.9919924442138},
#  {'name': 'Harlem Pizza Co',
#   'review_count': 209,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.8029069,
#   'longitude': -73.9510825},
#  {'name': 'Trapizzino',
#   'review_count': 258,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72043,
#   'longitude': -73.98894},
#  {'name': 'Bravo Pizza',
#   'review_count': 122,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.73863,
#   'longitude': -73.98727},
#  {'name': 'Il Mattone',
#   'review_count': 100,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.720799,
#   'longitude': -74.0091255},
#  {'name': 'Jumbo Pizza Coffee Shop',
#   'review_count': 84,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.8280452239988,
#   'longitude': -73.9489363226845},
#  {'name': 'Gotham Pizza',
#   'review_count': 172,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74381,
#   'longitude': -74.00295},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 69,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.706518,
#   'longitude': -74.007505},
#  {'name': 'Krave It Pizza & Sandwich Joint ',
#   'review_count': 45,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.764537,
#   'longitude': -73.916935},
#  {'name': 'Lucia Pizza',
#   'review_count': 589,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76032,
#   'longitude': -73.82813},
#  {'name': 'Pranzo Pizza & Pasta',
#   'review_count': 108,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7036301,
#   'longitude': -74.0101127},
#  {'name': 'Stage Door Pizzeria',
#   'review_count': 268,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.712121,
#   'longitude': -74.009704},
#  {'name': 'Pizza Secret',
#   'review_count': 199,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6808,
#   'longitude': -73.97764},
#  {'name': "Mark's Red Hook Pizza",
#   'review_count': 74,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6788288,
#   'longitude': -74.0113214},
#  {'name': 'Fumo',
#   'review_count': 156,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80284,
#   'longitude': -73.968119},
#  {'name': 'Gran Morsi',
#   'review_count': 426,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7142052394856,
#   'longitude': -74.0077535494539},
#  {'name': 'Emmy Squared Pizza: Upper East Side - New York',
#   'review_count': 203,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77564,
#   'longitude': -73.9565},
#  {'name': "Ben's Pizzeria",
#   'review_count': 298,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7304,
#   'longitude': -74.00027},
#  {'name': 'Cuts & Slices',
#   'review_count': 179,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6854737,
#   'longitude': -73.9203186},
#  {'name': 'Broadway Pizzeria',
#   'review_count': 121,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6933151509676,
#   'longitude': -73.9290830120444},
#  {'name': 'Non Solo Piada',
#   'review_count': 375,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75414,
#   'longitude': -73.99245},
#  {'name': "Luke's Lobster Brooklyn Bridge Park",
#   'review_count': 376,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70359,
#   'longitude': -73.99411},
#  {'name': "Ray's Pizza",
#   'review_count': 368,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824},
#  {'name': 'Little Italy Pizza',
#   'review_count': 309,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7918751922647,
#   'longitude': -73.9735541478506},
#  {'name': "Renato's Pizza Masters",
#   'review_count': 435,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7442813,
#   'longitude': -74.0503861},
#  {'name': "Libretto's Pizzeria",
#   'review_count': 202,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74727,
#   'longitude': -73.97721},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 271,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168},
#  {'name': 'Yankee Pizza',
#   'review_count': 39,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7267,
#   'longitude': -73.97727},
#  {'name': 'Carbone',
#   'review_count': 1387,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.728,
#   'longitude': -74.0001497},
#  {'name': 'Love & Dough',
#   'review_count': 224,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708},
#  {'name': 'La Villa',
#   'review_count': 552,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6743319055498,
#   'longitude': -73.9816949398812},
#  {'name': 'Mama Mia 44 SW',
#   'review_count': 728,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.759761,
#   'longitude': -73.992065},
#  {'name': 'Peperino NYC Pizza',
#   'review_count': 83,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77275912931571,
#   'longitude': -73.99077586611165},
#  {'name': 'Forcella',
#   'review_count': 449,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.711353,
#   'longitude': -73.9490983},
#  {'name': 'Dough Vale',
#   'review_count': 92,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70933,
#   'longitude': -73.95407},
#  {'name': 'Malatesta Trattoria',
#   'review_count': 1296,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73285,
#   'longitude': -74.00847},
#  {'name': 'Panzerotti Bites',
#   'review_count': 154,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.683715,
#   'longitude': -73.99227},
#  {'name': 'La Vera Pizzeria & Restaurant',
#   'review_count': 143,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.75408,
#   'longitude': -73.96889},
#  {'name': 'Public Display of Affection',
#   'review_count': 56,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67741,
#   'longitude': -73.98265},
#  {'name': "L'Artusi",
#   'review_count': 2055,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73372,
#   'longitude': -74.00513},
#  {'name': "Harry's Italian",
#   'review_count': 267,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7153762863468,
#   'longitude': -74.0139836332683},
#  {'name': 'Awesome Deli',
#   'review_count': 21,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7102999,
#   'longitude': -73.96629},
#  {'name': 'La Nonna Ristorante & Bar',
#   'review_count': 369,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718468787527,
#   'longitude': -73.9639185527139},
#  {'name': 'ZuriLee Restaurant',
#   'review_count': 303,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.654521,
# ...
#  {'name': 'Pies-n-Thighs',
#   'review_count': 3059,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.711191,
#   'longitude': -73.961424},
#  {'name': "Alfie's Pizza",
#   'review_count': 159,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69983,
#   'longitude': -73.83291},
#  {'name': 'Blaze Pizza',
#   'review_count': 188,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74036,
#   'longitude': -73.78695},
#  {'name': 'Gersi',
#   'review_count': 319,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.683438,
#   'longitude': -73.995711},
#  {'name': 'Pasta Louise',
#   'review_count': 206,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.666091,
#   'longitude': -73.9787254},
#  {'name': 'Pennsylvania 6 NYC',
#   'review_count': 562,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7483655239542,
#   'longitude': -73.9907944748688},
#  {'name': 'Little Italy Pizza',
#   'review_count': 265,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7778264823318,
#   'longitude': -73.9825049309491},
#  {'name': 'Prima Pizza',
#   'review_count': 54,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6937218,
#   'longitude': -73.8527069},
#  {'name': "Trattoria Dell'Arte",
#   'review_count': 1060,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.76545990643915,
#   'longitude': -73.98053136970677},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 279,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.754764,
#   'longitude': -73.987443},
#  {'name': "Sam's Place",
#   'review_count': 268,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.749270880468,
#   'longitude': -73.977082744053},
#  {'name': "Rosemary's",
#   'review_count': 1111,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.734863,
#   'longitude': -73.99974},
#  {'name': 'Jentana Pizza Restaurant',
#   'review_count': 70,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6375122070312,
#   'longitude': -73.9994735717773},
#  {'name': 'Serafina Fabulous Pizza',
#   'review_count': 372,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.7762350782493,
#   'longitude': -73.9623423504256},
#  {'name': 'Mezzaluna',
#   'review_count': 158,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.771125,
#   'longitude': -73.959251},
#  {'name': 'Brockenzo Neapolitan Pizza',
#   'review_count': 9,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.7503547668457,
#   'longitude': -73.9447784423828},
#  {'name': 'Grandaisy Bakery',
#   'review_count': 132,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.720041,
#   'longitude': -74.005867765337},
#  {'name': 'Zeppola Bakery',
#   'review_count': 54,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.752672726751186,
#   'longitude': -73.9891},
#  {'name': "Tony Novante's Pizzeria & Wing Boss",
#   'review_count': 127,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7781106,
#   'longitude': -74.0175598},
#  {'name': 'Da Nico Ristorante',
#   'review_count': 898,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71963,
#   'longitude': -73.99691},
#  {'name': 'A Pasta Bar',
#   'review_count': 390,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.72229,
#   'longitude': -74.00403},
#  {'name': 'Armandos Pizza',
#   'review_count': 41,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.646676,
#   'longitude': -73.883467},
#  {'name': 'Gemma',
#   'review_count': 693,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.72609,
#   'longitude': -73.99166},
#  {'name': '3 Giovani',
#   'review_count': 175,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72907,
#   'longitude': -73.99839},
#  {'name': 'Crif Dogs',
#   'review_count': 2095,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72707,
#   'longitude': -73.98379},
#  {'name': "Gino's Trattoria",
#   'review_count': 251,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.6605221493743,
#   'longitude': -73.9606475830078},
#  {'name': 'Giano Restaurant',
#   'review_count': 656,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7262256596862,
#   'longitude': -73.9840574049125},
#  {'name': 'Tenth Street Pasta & Pizza',
#   'review_count': 244,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74935270874642,
#   'longitude': -74.03135923715374},
#  {'name': 'La Bella Mariella Pizzeria',
#   'review_count': 57,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715406,
#   'longitude': -73.901038},
#  {'name': "Joey Pepperoni's Pizza",
#   'review_count': 92,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74094,
#   'longitude': -73.97891},
#  {'name': "Trattoria L'incontro",
#   'review_count': 1027,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.77648209257472,
#   'longitude': -73.91059675544598},
#  {'name': 'Whitmans Hudson Yards',
#   'review_count': 250,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75173481553854,
#   'longitude': -74.00146209413181},
#  {'name': 'Carlos Pizza',
#   'review_count': 47,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7045665,
#   'longitude': -73.9103926},
#  {'name': 'Prospect Pizza',
#   'review_count': 70,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.65869,
#   'longitude': -73.96034},
#  {'name': "Johnny's Pizzeria",
#   'review_count': 360,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.917609,
#   'longitude': -73.839425},
#  {'name': "Romeo's Pizzeria",
#   'review_count': 122,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.67389,
#   'longitude': -73.84348},
#  {'name': 'The Graham',
#   'review_count': 94,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7082405,
#   'longitude': -73.9431381},
#  {'name': 'Spaghetti Incident',
#   'review_count': 621,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7223153441439,
#   'longitude': -73.9899454318763},
#  {'name': "Rocky's Pizzeria",
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.64615,
#   'longitude': -73.971},
#  {'name': "Nonna Delia's",
#   'review_count': 64,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78224,
#   'longitude': -73.84619},
#  {'name': 'Manducatis',
#   'review_count': 148,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7445948529884,
#   'longitude': -73.9490695847509},
#  {'name': 'Blue Ribbon Fried Chicken - East Village',
#   'review_count': 949,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.724179701505,
#   'longitude': -73.9904544943272},
#  {'name': 'Puglia Ristorante',
#   'review_count': 569,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7181606872639,
#   'longitude': -73.9976975651144},
#  {'name': 'Brooklyn Pizza Crew',
#   'review_count': 163,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.67279,
#   'longitude': -73.95053},
#  {'name': 'Ungaro Coal Fired Pizza Cafe',
#   'review_count': 39,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.62624,
#   'longitude': -74.13315},
#  {'name': "Benny Tudino's Pizzeria",
#   'review_count': 703,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74422,
#   'longitude': -74.02915},
#  {'name': 'Zesty Pizzeria & Salumeria',
#   'review_count': 101,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7837296,
#   'longitude': -73.950798},
#  {'name': 'The Sicilian',
#   'review_count': 159,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.65992,
#   'longitude': -73.98059},
#  {'name': 'Antika',
#   'review_count': 462,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.76466,
#   'longitude': -73.91722},
#  {'name': 'Aita Trattoria',
#   'review_count': 218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6712095108944,
#   'longitude': -73.9579255586597},
#  {'name': "Gino's Pizza",
#   'review_count': 190,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.77535,
#   'longitude': -73.95121},
#  {'name': 'Centro Pizza',
#   'review_count': 57,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7717910087337,
#   'longitude': -73.9563909799841},
#  {'name': 'La Villa Pizzeria',
#   'review_count': 143,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6112945152771,
#   'longitude': -74.0082534402609},
#  {'name': 'Anthony & Son Panini Shoppe',
#   'review_count': 385,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71793570773689,
#   'longitude': -73.94514389620791},
#  {'name': 'Wild Park Slope',
#   'review_count': 325,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.678273,
#   'longitude': -73.979376},
#  {'name': 'Pisillo Italian Panini',
#   'review_count': 653,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.710558,
#   'longitude': -74.007594},
#  {'name': 'Sheshe Pizzeria',
#   'review_count': 41,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7999475,
#   'longitude': -73.9621495},
#  {'name': 'Trattoria Trecolori',
#   'review_count': 2487,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.759876,
#   'longitude': -73.986767},
#  {'name': 'Cafe Fiorello',
#   'review_count': 845,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.77134,
#   'longitude': -73.9819051},
#  {'name': 'Don Filippo Restaurant',
#   'review_count': 177,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.774562,
#   'longitude': -73.958892},
#  {'name': 'Roma Pizza & Restaurant',
#   'review_count': 191,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.674609,
#   'longitude': -73.975037},
#  {'name': 'Popina',
#   'review_count': 76,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.687361962701,
#   'longitude': -74.0014251909241},
#  {'name': 'Dante',
#   'review_count': 507,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72879,
#   'longitude': -74.00165},
#  {'name': 'Gennaro',
#   'review_count': 408,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.79178,
#   'longitude': -73.9718},
#  {'name': "Tony's and Orazio Pizza",
#   'review_count': 154,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7010231018066,
#   'longitude': -73.9226455688477},
#  {'name': 'La Trattoria',
#   'review_count': 83,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.75161,
#   'longitude': -73.97069},
#  {'name': "Basile's Pizza",
#   'review_count': 303,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.736978968163,
#   'longitude': -74.030820734929},
#  {'name': 'Da Marino',
#   'review_count': 590,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.76102,
#   'longitude': -73.98526},
#  {'name': "Sabrina's Pizzeria & Restaurant",
#   'review_count': 32,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.708374,
#   'longitude': -73.958327},
#  {'name': 'Palermo Restaurant & Bar',
#   'review_count': 268,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7769088448014,
#   'longitude': -73.9212289547099},
#  {'name': 'American Retro',
#   'review_count': 215,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76618,
#   'longitude': -73.99409},
#  {'name': 'Delizia 92',
#   'review_count': 279,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78152,
#   'longitude': -73.94886},
#  {'name': "Basile's Pizza",
#   'review_count': 303,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.736978968163,
#   'longitude': -74.030820734929},
#  {'name': 'Da Marino',
#   'review_count': 590,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.76102,
#   'longitude': -73.98526},
#  {'name': "Sabrina's Pizzeria & Restaurant",
#   'review_count': 32,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.708374,
#   'longitude': -73.958327},
#  {'name': 'Palermo Restaurant & Bar',
#   'review_count': 268,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7769088448014,
#   'longitude': -73.9212289547099},
#  {'name': 'American Retro',
#   'review_count': 215,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76618,
#   'longitude': -73.99409},
#  {'name': 'Delizia 92',
#   'review_count': 279,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.78152,
#   'longitude': -73.94886},
#  {'name': "Katz's Delicatessen",
#   'review_count': 13555,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.722237,
#   'longitude': -73.9875259},
#  {'name': "Tony's Pizza",
#   'review_count': 51,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.664924,
#   'longitude': -73.923379},
#  {'name': 'Spicy Pizza',
#   'review_count': 33,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7448731218168,
#   'longitude': -73.9208319089972},
#  {'name': 'High Street On Hudson',
#   'review_count': 439,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73888,
#   'longitude': -74.00574},
#  {'name': 'Carmentas Italian Specialties',
#   'review_count': 124,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70114,
#   'longitude': -73.92677},
#  {'name': 'Parm',
#   'review_count': 814,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': 'Trattoria Napoli',
#   'review_count': 144,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77794,
#   'longitude': -74.01825},
#  {'name': 'The Commodore',
#   'review_count': 607,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7138257110445,
#   'longitude': -73.9556050300598},
#  {'name': 'Stella 34 Trattoria',
#   'review_count': 699,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75049486336486,
#   'longitude': -73.98798861987918},
#  {'name': 'Last Dragon Pizza',
#   'review_count': 14,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.5907651687874,
#   'longitude': -73.7960245609283},
#  {'name': 'The Roost',
#   'review_count': 149,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7290935,
#   'longitude': -73.9785323},
#  {'name': 'Villa Mia Pizza',
#   'review_count': 48,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.6694983,
#   'longitude': -73.992818},
#  {'name': 'Belli Osteria',
#   'review_count': 278,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6835199838354,
#   'longitude': -73.9669024162476},
#  {'name': 'Blaze Pizza',
#   'review_count': 229,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.738388,
#   'longitude': -74.1708115},
#  {'name': 'Cappone’s Salumeria',
#   'review_count': 75,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.742106,
#   'longitude': -74.005587},
#  {'name': "Little Luzzo's",
#   'review_count': 179,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.786295,
#   'longitude': -73.9515269},
#  {'name': 'The New Taste of Italy',
#   'review_count': 6,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6924462067728,
#   'longitude': -73.8605820873467},
#  {'name': 'Fresh Salt',
#   'review_count': 411,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70707,
#   'longitude': -74.00244},
#  {'name': "Sammy Sam's Pizzeria",
#   'review_count': 13,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7944610511506,
#   'longitude': -74.0122780948877},
#  {'name': "Sid Gold's Request Room",
#   'review_count': 127,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7459564208984,
#   'longitude': -73.9935836791992},
#  {'name': 'Brothers Pizza',
#   'review_count': 56,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.66341,
#   'longitude': -73.99468},
#  {'name': 'Amore Pizzeria',
#   'review_count': 511,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7693570273757,
#   'longitude': -73.8341404931405},
#  {'name': "Tony's Brick Oven",
#   'review_count': 113,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.615321,
#   'longitude': -74.067035},
#  {'name': 'Pizza School NYC',
#   'review_count': 174,
#   'rating': 5.0,
#   'price': '$$$$',
#   'latitude': 40.71637,
#   'longitude': -73.98872},
#  {'name': 'Amici Ristorante',
#   'review_count': 130,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71981,
#   'longitude': -73.99722},
#  {'name': 'Pronto Pizzeria',
#   'review_count': 161,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76346,
#   'longitude': -73.90886},
#  {'name': 'Columbia Pizza',
#   'review_count': 9,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.71707,
#   'longitude': -73.98043},
#  {'name': 'Pronto',
#   'review_count': 21,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7135184985884,
#   'longitude': -73.9145063912041},
#  {'name': 'Bevacco',
#   'review_count': 260,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.699206213709665,
#   'longitude': -73.99232},
#  {'name': 'Pizza Sam',
#   'review_count': 192,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756003,
#   'longitude': -73.878524},
#  {'name': 'Cafe Viva',
#   'review_count': 267,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.795335,
#   'longitude': -73.970684},
#  {'name': "Emilio's of Morris Park",
#   'review_count': 190,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.849121,
#   'longitude': -73.854675},
#  {'name': 'Smorgasburg - Prospect Park',
#   'review_count': 318,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.66642,
#   'longitude': -73.97535}]

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
1.  Review Count is proportionally skewed between 0-2000 for most of the businesses (~700). 
2.  Most of the businesses have a median rating of "4.0". There are less than 75 of the businesses that have a rating of 3
    and less as well greater than 5
3.  Majority of the businesses are priced on the two lower price ranges. Less than 75 of the businesses are priced on the
    higher side. 
"""

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
Compared to the lower price, a higher price is associated with a higher rating above the 4.0 rating. 
For ratings for 3.5 or less, the higher price businesses got lower ratings.  
"""

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5))

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
The most reviews were done at ratings 3.5-4.5. The most reviews were done at the 4.0 rating level. At the 5.0 rating level,
there were not many reviews.  Therefore the highest rating doesn't correlate with the most reviews, but the higher ratings
do have more ratings than the lower ones.
"""

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
# %pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from folium) (2.27.1)
# Collecting jinja2>=2.9
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 5.3 MB/s eta 0:00:01
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from folium) (1.22.3)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp310-cp310-macosx_10_9_x86_64.whl (13 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->folium) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->folium) (3.3)
# Installing collected packages: MarkupSafe, jinja2, branca, folium
# Successfully installed MarkupSafe-2.1.1 branca-0.5.0 folium-0.12.1.post1 jinja2-3.1.2
# WARNING: You are using pip version 21.2.3; however, version 22.1.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Replace None with appropriate code

# Import the library
import folium

# Set up center latitude and longitude
center_lat = full_dataset[0]["latitude"]
center_long = full_dataset[0]["longitude"]
# Initialize map with center lat and long
yelp_map = folium.Map([center_lat,center_long], zoom_start = 15)

# Adjust this limit to see more or fewer businesses
limit=100

for business in full_dataset[:limit]:
    # Extract information about business
    lat = business["latitude"]
    long = business["longitude"]
    name = business["name"]
    rating = business["rating"]
    price = business["price"]
    details = "{}\nPrice: {} Rating:{}".format(name,price,rating)
    
    # Create popup with relevant details
    popup = folium.Popup(details, parse_html = True)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker(location=[lat, long], popup=popup)
    
    marker.add_to(yelp_map)
    
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22a773958e439b8a5677f14638a0c552 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22a773958e439b8a5677f14638a0c552&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_22a773958e439b8a5677f14638a0c552 = L.map(
#                 &quot;map_22a773958e439b8a5677f14638a0c552&quot;,
#                 {
#                     center: [40.72308755605564, -73.99453001177575],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a668838390aab9ab4011d0fea5bce8b3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_22a773958e439b8a5677f14638a0c552);
#
#
#             var marker_434ae5682f9dd2d71356035a529027b2 = L.marker(
#                 [40.72308755605564, -73.99453001177575],
#                 {}
#             ).addTo(map_22a773958e439b8a5677f14638a0c552);
#
#
#         var popup_c9143cf7e7e86bd9f9e3f22c1f2c699e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3017590d2c809f01737f7a6d3efa070d = $(`&lt;div id=&quot;html_3017590d2c809f01737f7a6d3efa070d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prince Street Pizza Price: $ Rating:4.5&lt;/div&gt;`)[0];
#             popup_c9143cf7e7e86bd9f9e3f22c1f2c699e.setContent(html_3017590d2c809f01737f7a6d3efa070d);
#
#
#         marker_434ae5682f9dd2d71356035a529027b2.bindPopup(popup_c9143cf7e7e86bd9f9e3f22c1f2c699e)
#         ;
#
#
#
#
#             var marker_ab89c84d0737d26116a8844ec99d8a2f = L.marker(
#                 [40.70274718768062, -73.99343490196397],
#                 {}
#             ).addTo(map_22a773958e439b8a5677f14638a0c552);
#
#
#         var popup_97f8c113da274c7395f702c62d6aa2f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e37c48044a46208e295d1bc929535ed2 = $(`&lt;div id=&quot;html_e37c48044a46208e295d1bc929535ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Juliana&amp;#39;s Price: $$ Rating:4.5&lt;/div&gt;`)[0];
#             popup_97f8c113da274c7395f702c62d6aa2f6.setContent(html_e37c48044a46208e295d1bc929535ed2);
#
#
#         marker_ab89c84d0737d26116a8844ec99d8a2f.bindPopup(popup_97f8c113da274c7395f702c62d6aa2f6)
#         ;
#
#
#
#
#             var marker_ed45b6ce08b8df2b016e172eafa24c13 = L.marker(
#                 [40.7215934960083, -73.9955956044561],
#                 {}
#             ).addTo(map_22a773958e439b8a5677f14638a0c552);
#
#
#         var popup_0f87fd228e642602306e3e0531b4a31c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ce3afe897229ef56cf9a85e144eb3478 = $(`&lt;div id=&quot;html_ce3afe897229ef56cf9a85e144eb3478&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lombardi&amp;#39;s Pizza Price: $$ Rating:4.0&lt;/div&gt;`)[0];
#             popup_0f87fd228e642602306e3e0531b4a31c.setContent(html_ce3afe897229ef56cf9a85e144eb3478);
#
#
#         marker_ed45b6ce08b8df2b016e172eafa24c13.bindPopup(popup_0f87fd228e642602306e3e0531b4a31c)
#         ;
#
#
#
#
#             var marker_3bf2f3686dab2fac660c77931bb59461 = L.marker(
#                 [40.681840746711224, -74.0003327],
#                 {}
#             ).addTo(map_22a773958e439b8a5677f14638a0c552);
#
#
#         var popup_ddecb725c214d4bf695b24e20d105fa1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_43fa70261203804608612187eb2f418f = $(`&lt;div id=&quot;html_43fa70261203804608612187eb2f418f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lucali Price: $$ Rating:4.0&lt;/div&gt;`)[0];
#             popup_ddecb725c214d4bf695b24e20d105fa1.setContent(html_43fa70261203804608612187eb2f418f);
#
#
#         marker_3bf2f3686dab2fac660c77931bb59461.bindPopup(popup_ddecb725c214d4bf695b24e20d105fa1)
#         ;
#
#
#
#
#             var marker_c44cf1a7b09a95bc6a181790c5e0e478 = L.marker(
#                 [40.722766, -73.996233],
#                 {}
#             ).addTo(map_22a773958e439b8a5677f14638a0c552);
#
#
#         var popup_46450d16c4d27e85c50dc99b584647a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d43376cd7707fc8a654e0ab235244fb1 = $(`&lt;div id=&quot;html_d43376cd7707fc8a654e0ab235244fb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rubirosa Price: $$ Rating:4.5&lt;/div&gt;`)[0];
#             popup_46450d16c4d27e85c50dc99b584647a1.setContent(html_d43376cd7707fc8a654e0ab235244fb1);
#
#
#         marker_c44cf1a7b09a95bc6a181790c5e0e478.bindPopup(popup_46450d16c4d27e85c50dc99b584647a1)
#         ;
#
#
#
#
#             var marker_943fc49321433660b34eec0d72bdc6a9 = L.marker(
#                 [40.73060076, -74.00215997],
#                 {}
#             ).addTo(map_22a773958e439b8a5677f14638a0c552);
#
#
#         var popup_55a1841fdfd775eebe

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
